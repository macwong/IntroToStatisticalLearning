# %% [markdown]
# # Chapter 2 - Statistical Learning

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("datasets\Advertising.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# Unnamed: 0    200 non-null int64
# TV            200 non-null float64
# radio         200 non-null float64
# newspaper     200 non-null float64
# sales         200 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
X = data[['TV','radio', 'newspaper']]
Y = data['sales']

# %%
sns.regplot(x = X["TV"], y = Y)

# %%
g = sns.PairGrid(data, y_vars=["sales"], x_vars=["TV", "radio", 'newspaper'], size=4)
g.map(sns.regplot)

# %% [markdown]
# In this example:
# * $X$ => input variables => features => "TV", "radio" and "newspaper"
# * $Y$ => output variables => dependent => "sales"

# %% [markdown]
# ### General Formula
# $
# Y = f(X) + \epsilon
# $
#
# (Assuming that X and Y have a relationship)
#
# #### Features
#
# $X$ are the features to process
#
# #### Function
#
# Where f is fixed but unknown function that processes $X$ features
#
# $f$ represents the systematic information that X provides about Y
#
# $f$ is unknown, so we need to estimate this
#
# #### Epsilon
#
# $
# \epsilon
# $ is a random error term with an approximate mean of 0
#
# Also known as the error term, residual
#
# The error term essentially means that the model is not completely accurate and results in differing results during real-world applications

# %% [markdown]
# > *Statistical learning refers to a set of approaches for estimating $f$*

# %% [markdown]
# ### Why estimate $f$?

# %% [markdown]
# #### Prediction

# %% [markdown]
# Identifies what might happen in the future, e.g.:
# * How much will a house increase in price?
#
# $X$ is available, but $Y$ cannot be easily obtained. Therefore we predict it:
#
# $\hat{Y} = \hat{f}(X)$
#
# $\hat{f}$ is our estimate for $f$, and $\hat{Y}$ is our resulting prediction for $Y$
#
# The accuracy of $\hat{Y}$ as a prediction for $Y$ depends on two quantities: the reducible and irreducible error:
# * Reducible error: can be reduced / improved on. e.g. $\hat{f}$ can be improved
# * Irreducible error: will always exist, cannot reduce

# %% [markdown]
# #### Inference

# %% [markdown]
# Reaching a conclusion based on known facts or evidence, e.g.:
# * Which media generate the biggest boost in sales?

# %% [markdown]
# ### How do we estimate $f$?

# %% [markdown]
# Using training data to teach our method to estimate $f$
#
# Training data consists of:
#
# $\{(x_1, y_1),\hspace{1mm}(x_2, y_2),\hspace{1mm}\cdots,\hspace{1mm}(x_n, y_n)\}$
# where
# $x_i = (x_{i1},\hspace{1mm}x_{i2},\hspace{1mm}\cdots,\hspace{1mm}x_{ip})^T$
#
# $i$ = 1, 2, ..., $n$
#
# $j$ = 1, 2, ..., $p$
#
# $n$ = number of observations / records
#
# $p$ = number of features

# %% [markdown]
# Our goal is to apply a statistical learning method to the training data
# in order to estimate the unknown function $f$
#
# $Y \approx \hat{f}(X)$ for any observation $(X, Y)$

# %% [markdown]
# ### Prediction Accuracy vs Model Interpretability
#
# If we want to make inferences for the data, then having it interpretable is more important
#
# However, if we just want an accurate prediction, then interpretability isn't always as important.
#
# Bear in mind that some more flexible models can lead to overfitting

# %% [markdown]
# ### Supervised vs Unsupervised
#
# Supervised - Knowing prior "labels" to use to make predictions
# * Linear Regression
# * Logistic Regression
# * SVM
#
# Unsupervised - Not knowing what to predict
# * Clustering

# %% [markdown]
# ### Regression vs Classification
#
# Regression - Quantitative predictions
# * Predict house prices
# * Predict Age
#
# Classification - Qualitative predictions
# * Predict survival of Titanic
# * Predict blood type of patient

# %% [markdown]
# ## Assessing Model Accuracy

# %% [markdown]
# ### Measuring the quality of fit
#
# Need some way to measure how well the predictions match the observed data.
#
# In regression, the most commonly used measure is the mean squared error (MSE)
#
# $MSE = \frac{1}n \sum \limits^{n}_{i = 1} (y_i - \hat{f}(x_i))^2$
#
# or
#
# $MSE = \frac{1}n
# \sum \limits^{n}_{i = 1}
# (y_i - \hat{y}_i)^2$
#
#
# $\hat{f}(x_i)$ is the prediction that $\hat{f}$ gives for the $i^{th}$ observation

# %% [markdown]
# ### Example
#
# The following diagram shows three models:
# * Linear
# * Non-linear (general)
# * Non-linear (crazy overfitting)
#
# The model that overfits has the lowest MSE for the training set, but the highest MSE for the test set
#
# The linear model has a reasonably consistent MSE, but that doesn't mean it's good
#
# The general non-linear model has the best MSE for the test set, which generally means it's the best model for the data
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)
